# %% [markdown]
# # <center> Aplicación en Bioestadística: Análisis de Depresión en RR.SS.
# ## <center>AI Saturdays Euskadi Donostia 2020

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# **Read data into a Pandas DataFrame**

# %%
data = pd.read_csv('OSF_socialmedia_data.csv')
data.head()
# Out:
#    Unnamed: 0  Participant        Date      Day      Time     Session.Name  \
# 0           1       115091  05/02/2017  Tuesday  10:00:06  Daily questions
# 1           2       115091  05/02/2017  Tuesday  12:02:48  Daily questions
# 2           3       115091  05/02/2017  Tuesday  14:03:02  Daily questions
# 3           4       115091  05/02/2017  Tuesday  16:34:28  Daily questions
# 4           5       115091  05/02/2017  Tuesday  18:00:00  Daily questions
#
#    Notification.No  LifePak.Download.No  Responded  Completed.Session  ...  \
# 0                1                    1          1                  1  ...
# 1                2                    1          1                  1  ...
# 2                3                    1          1                  1  ...
# 3                4                    1          1                  1  ...
# 4                5                    1          0                  0  ...
#
#    Loneliness Concentrat  LossOfInt  Inferior  Hopeless  Stress  PSMU  \
# 0        61.0       64.0       68.0      50.0      56.0    73.0  66.0
# 1        57.0       70.0       58.0      37.0      56.0    67.0   0.0
# 2        44.0       70.0       67.0      26.0      38.0    39.0  63.0
# 3        56.0       79.0       89.0      30.0      20.0    60.0  67.0
# 4         NaN        NaN        NaN       NaN       NaN     NaN   NaN
#
#     AutoPSMU  News  Active
# 0         66  39.0    38.0
# 1  #skipped#  27.0    23.0
# 2         56  34.0    36.0
# 3         68  29.0    23.0
# 4        NaN   NaN     NaN
#
# [5 rows x 26 columns]
